# %%
import numpy as np
from random import random
from sklearn.model_selection import train_test_split
# random value takes no. between 0 & 1

# %%
import numpy as np
from random import random
from sklearn.model_selection import train_test_split
import tensorflow as tf


"""

x containing 2000 samples, where each sample has two features (random numbers between 0 and 0.5). 
It also creates a corresponding dataset y where each element is the sum of the two features in the corresponding row of x.

"""

def generate_dataset(num_samples, test_size):
    x = np.array([[random()/2 for _ in range(2)] for _ in range(num_samples)])
    
    y = np.array([[i[0] + i[1]] for i in x])

    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size)

    return x_train, x_test, y_train, y_test


if __name__ == "__main__":
    x_train, x_test, y_train, y_test = generate_dataset(5000, 0.3)
    # print("x_test: \n {}".format(x_test))
    # print("y_test: \n {}".format(y_test))

    
    # model building
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(5, input_dim = 2, activation = "sigmoid"),
        tf.keras.layers.Dense(1,  activation = "sigmoid")
    ])

    # compiling model
    optimiser = tf.keras.optimizers.SGD(learning_rate = 0.1)
    model.compile(optimizer=optimiser, loss="MSE")

    # training the model
    model.fit(x_train, y_train, epochs=100)

    # evaluating model
    print("\nModel Evaluation:")
    model.evaluate(x_test, y_test, verbose=1)

    # making predictions
    data = np.array([[0.1, 0.2], [0.2, 0.2]])
    predictions = model.predict(data)

    print("\nSome Predictions:")
    for d, p in zip(data, predictions):
        print("{} + {} = {}".format(d[0], d[1], p[0]))
# Out:
# Epoch 1/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0407
# Epoch 2/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0422
# Epoch 3/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0430
# Epoch 4/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0418
# Epoch 5/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0419
# Epoch 6/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0417
# Epoch 7/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0401
# Epoch 8/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0403
# Epoch 9/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0397
# Epoch 10/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0405
# Epoch 11/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0406
# Epoch 12/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0383
# Epoch 13/100
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0385
# Epoch 14/100
# ...
