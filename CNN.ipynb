# %%
"""

There are two main components of CNN:
1. Convolution
2. Pooling


Convolution contains following things 
Kernel = gird of weights
Kernel is "applied" to image
Traditionally used for image processing

"""
# Out:
# '\n\nThere are two main components of CNN:\n1. Convolution\n2. Pooling\n\n\nConvolution contains following things \nKernel = gird of weights\nKernel is "applied" to image\nTraditionally used for image processing\n\n'

# %%
import json
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow.keras as keras



DATA_PATH = "data.json"


def load_data(data_path):
    with open(data_path, "r") as fp:
        data = json.load(fp)


    X = np.array(data["mfcc"])
    y = np.array(data["labels"])
    return X, y


def prepare_datasets(test_size, validation_size):
    # load data
    X, y = load_data(DATA_PATH)

    # create train/test split
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size)

    # create train/validate split
    X_train, X_validation, y_train, y_validation = train_test_split(X_train, y_train, test_size=validation_size)

    # 3d array is used while working with Tensorflow for CNN
    X_train = X_train[..., np.newaxis] # 4d array ---> (num_samples, 130, 13, 1)
    X_validation = X_validation[..., np.newaxis]
    X_test = X_test[..., np.newaxis]

    return X_train, X_validation, X_test, y_train, y_validation, y_test


def build_model(input_shape):
    # create model
    model = keras.Sequential()

    # 1st convolutional layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 2nd convolutional layer
    model.add(keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPool2D((3, 3), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # 3rd convolutional layer
    model.add(keras.layers.Conv2D(32, (2, 2), activation='relu', input_shape=input_shape))
    model.add(keras.layers.MaxPool2D((2, 2), strides=(2, 2), padding='same'))
    model.add(keras.layers.BatchNormalization())

    # flatten the output and feed it into dense layer
    model.add(keras.layers.Flatten())
    model.add(keras.layers.Dense(64, activation='relu'))
    model.add(keras.layers.Dropout(0.3))

    # output layer using softmax
    model.add(keras.layers.Dense(10, activation='softmax'))

    return model



def predict(model, X, y):
    X = X[np.newaxis, ...]

    # prediction = [ [ 0.1, 0.2, 0.3, ....] ]
    prediction = model.predict(X)

    # extracting index with max val
    predicted_index = np.argmax(prediction, axis=1) # gives index and we wan't to map it to the json file
    print("Expected index: {}, Predicted_index: {}".format(y, predicted_index))


if __name__ == "__main__":
    # create train, validation and test sets
    X_train, X_validation, X_test, y_train, y_validation, y_test = prepare_datasets(0.25, 0.2)

    # build the CNN network
    input_shape = (X_train.shape[1], X_train.shape[2], X_train.shape[3])
    model = build_model(input_shape)

    # compile the network
    optimizer = keras.optimizers.Adam(learning_rate=0.0001)
    model.compile(optimizer=optimizer,
                 loss="sparse_categorical_crossentropy",
                 metrics=['accuracy'])

    # train the CNN
    model.fit(X_train, y_train, validation_data=(X_validation, y_validation), batch_size=32, epochs=30)

    # evaluate the CNN on the test set
    test_error, test_accuracy = model.evaluate(X_test, y_test, verbose=1)
    print("Accuracy on test set is: {}".format(test_accuracy))

    # make prediction on a sample
    X = X_test[45]
    y = y_test[45]
    predict(model, X, y)
# Out:
# Epoch 1/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 6s 125ms/step - accuracy: 0.0898 - loss: 3.1616 - val_accuracy: 0.0444 - val_loss: 3.7372
# Epoch 2/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.0860 - loss: 2.9954 - val_accuracy: 0.0889 - val_loss: 3.0247
# Epoch 3/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.1931 - loss: 2.4712 - val_accuracy: 0.1111 - val_loss: 2.6750
# Epoch 4/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.1962 - loss: 2.4988 - val_accuracy: 0.1778 - val_loss: 2.4631
# Epoch 5/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.3308 - loss: 2.1093 - val_accuracy: 0.2222 - val_loss: 2.3309
# Epoch 6/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.3372 - loss: 1.9678 - val_accuracy: 0.3111 - val_loss: 2.2376
# Epoch 7/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.3826 - loss: 1.7195 - val_accuracy: 0.4000 - val_loss: 2.1660
# Epoch 8/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.3742 - loss: 1.6959 - val_accuracy: 0.3778 - val_loss: 2.0955
# Epoch 9/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.4770 - loss: 1.5203 - val_accuracy: 0.3556 - val_loss: 2.0291
# Epoch 10/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5120 - loss: 1.4229 - val_accuracy: 0.3556 - val_loss: 1.9677
# Epoch 11/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.5907 - loss: 1.2811 - val_accuracy: 0.3778 - val_loss: 1.9024
# Epoch 12/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.5291 - loss: 1.2667 - val_accuracy: 0.3778 - val_loss: 1.8360
# Epoch 13/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.5512 - loss: 1.3141 - val_accuracy: 0.4222 - val_loss: 1.7731
# Epoch 14/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step - accuracy: 0.6777 - loss: 1.0713 - val_accuracy: 0.4222 - val_loss: 1.7180
# Epoch 15/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.7073 - loss: 0.9463 - val_accuracy: 0.4444 - val_loss: 1.6608
# Epoch 16/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.7108 - loss: 0.8526 - val_accuracy: 0.4889 - val_loss: 1.5866
# Epoch 17/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step - accuracy: 0.7510 - loss: 0.8511 - val_accuracy: 0.5111 - val_loss: 1.5120
# Epoch 18/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.7423 - loss: 0.7943 - val_accuracy: 0.5778 - val_loss: 1.4458
# Epoch 19/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 71ms/step - accuracy: 0.7845 - loss: 0.7744 - val_accuracy: 0.5778 - val_loss: 1.3832
# Epoch 20/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.7175 - loss: 0.7731 - val_accuracy: 0.6000 - val_loss: 1.3297
# Epoch 21/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 72ms/step - accuracy: 0.8109 - loss: 0.6125 - val_accuracy: 0.6000 - val_loss: 1.2820
# Epoch 22/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8425 - loss: 0.6219 - val_accuracy: 0.6000 - val_loss: 1.2323
# Epoch 23/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.8255 - loss: 0.5714 - val_accuracy: 0.6444 - val_loss: 1.1814
# Epoch 24/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 79ms/step - accuracy: 0.8173 - loss: 0.5418 - val_accuracy: 0.6444 - val_loss: 1.1301
# Epoch 25/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 83ms/step - accuracy: 0.7924 - loss: 0.6190 - val_accuracy: 0.6444 - val_loss: 1.0769
# Epoch 26/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 81ms/step - accuracy: 0.9044 - loss: 0.5067 - val_accuracy: 0.6889 - val_loss: 1.0324
# Epoch 27/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8310 - loss: 0.5807 - val_accuracy: 0.6889 - val_loss: 0.9956
# Epoch 28/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8553 - loss: 0.5075 - val_accuracy: 0.6889 - val_loss: 0.9594
# Epoch 29/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 1s 86ms/step - accuracy: 0.8367 - loss: 0.5553 - val_accuracy: 0.6889 - val_loss: 0.9258
# Epoch 30/30
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9073 - loss: 0.4601 - val_accuracy: 0.7111 - val_loss: 0.8901
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.6458 - loss: 1.0743
# Accuracy on test set is: 0.6666666865348816
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 469ms/step
# Expected index: 1, Predicted_index: [5]
